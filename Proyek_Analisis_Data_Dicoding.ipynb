# %% [markdown]
# # Proyek Analisis Data E-commerce
#
# Name: Rizka Irianty Naharuddin
#
# E-mail: kikaranty@gmail.com

# %% [markdown]
# ### Business Questions
# 1. Which items are the most popular?
# 2. Which cities have the highest revenue?
# 3. How delivery time affect customer review scores?
# 4. How is the company performance based on customer review scores?
# 5. Who are the top customers based on their recency, frequency, and monetary value?

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !unzip "E-commerce-public-dataset"
# Out:
# Archive:  E-commerce-public-dataset.zip
# replace E-Commerce Public Dataset/customers_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: E-Commerce Public Dataset/customers_dataset.csv
# replace E-Commerce Public Dataset/geolocation_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: E-Commerce Public Dataset/geolocation_dataset.csv
#  extracting: E-Commerce Public Dataset/New Text Document.txt
#   inflating: E-Commerce Public Dataset/order_items_dataset.csv
#   inflating: E-Commerce Public Dataset/order_payments_dataset.csv
#   inflating: E-Commerce Public Dataset/order_reviews_dataset.csv
#   inflating: E-Commerce Public Dataset/orders_dataset.csv
#   inflating: E-Commerce Public Dataset/product_category_name_translation.csv
#   inflating: E-Commerce Public Dataset/products_dataset.csv
#   inflating: E-Commerce Public Dataset/sellers_dataset.csv

# %% [markdown]
# ### Data Wrangling

# %%
customers_df = pd.read_csv("E-Commerce Public Dataset/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
print("Duplicate values: ", customers_df.duplicated().sum())
print(customers_df.isnull().sum())
customers_df.info()
# Out:
# Duplicate values:  0
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
order_items_df = pd.read_csv("E-Commerce Public Dataset/order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
print("Duplicate values: ", order_items_df.duplicated().sum())
print(order_items_df.isnull().sum())
order_items_df.info()
# Out:
# Duplicate values:  0
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
orders_df = pd.read_csv("E-Commerce Public Dataset/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
print("Duplicate values: ", orders_df.duplicated().sum())
print(orders_df.isnull().sum())
orders_df.info()
# Out:
# Duplicate values:  0
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
# ...

# %%
products_df = pd.read_csv("E-Commerce Public Dataset/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
print("Duplicate values: ", products_df.duplicated().sum())
print(products_df.isnull().sum())
products_df.info()
# Out:
# Duplicate values:  0
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
# ...

# %%
products_trans_df = pd.read_csv("E-Commerce Public Dataset/product_category_name_translation.csv")
products_trans_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
print("Duplicate values: ", products_trans_df.duplicated().sum())
print(products_trans_df.isnull().sum())
products_trans_df.info()
# Out:
# Duplicate values:  0
# product_category_name            0
# product_category_name_english    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
order_reviews_df = pd.read_csv("E-Commerce Public Dataset/order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
print("Duplicate values: ", order_reviews_df.duplicated().sum())
print(order_reviews_df.isnull().sum())
order_reviews_df.info()
# Out:
# Duplicate values:  0
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# **Data Cleaning**
#
# To do:
#
# - Change all date columns in `orders_df` into datetime data type
# - Drop records from `products_df` where `product_category_name` is empty
# - Delete underscores (_) from product names in `products_trans_df` and `products_df`
# - Filter out records in orders_df where order_delivered_customer_date, order_delivered_carrier_date, and order_approved_at columns are missing

# %%
datetime_columns = ['order_approved_at', 'order_delivered_customer_date', 'order_delivered_carrier_date', 'order_purchase_timestamp', 'order_estimated_delivery_date']

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
products_df.dropna(inplace = True)

# %%
products_df['product_category_name'] = products_df['product_category_name'].apply(lambda x: x.replace("_", " "))
products_trans_df['product_category_name'] = products_trans_df['product_category_name'].apply(lambda x: x.replace("_", " "))
products_trans_df['product_category_name_english'] = products_trans_df['product_category_name_english'].apply(lambda x: x.replace("_", " "))

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
products_df.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
orders_df.describe(include="all")
# Out:
# <ipython-input-24-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-24-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-24-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# ...

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
for index, row in orders_df.iterrows():
  if row['delivery_time'] < 0:
    orders_df.drop(index, inplace = True)
orders_df[orders_df['delivery_time'] < 0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, delivery_time]
# Index: []

# %%
orders_df.delivery_time.hist()
# Out:
# <Axes: >

# %%
customer_orders_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customer_orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
customer_orders_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41735
# RJ    12851
# MG    11630
# RS     5465
# PR     5045
# SC     3635
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %%
customer_orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96458
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama mesa banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000        32340.000000
# ...

# %%
prod_eng_df = pd.merge(
    left=products_df,
    right=products_trans_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
prod_eng_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
prod_eng_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head()
# Out:
# product_category_name_english
# bed bath table     3029
# sports leisure     2867
# furniture decor    2657
# health beauty      2444
# housewares         2335
# Name: product_id, dtype: int64

# %%
product_item_df = pd.merge(
    left=order_items_df,
    right=prod_eng_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet shop
# ...

# %%
#product_item_df[product_item_df.product_category_name.isnull()]

# %%
order_reviews_df.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %%
rev_product_item_df = pd.merge(
    left=product_item_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
rev_product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet shop
# ...

# %%
all_df = pd.merge(
    left=customer_orders_df,
    right=rev_product_item_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
rev_product_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet shop
# ...

# %%
all_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_time', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_item_id', 'product_id',
#        'seller_id', 'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %% [markdown]
# Drop unnecessary columns

# %%
all_df.drop(['review_answer_timestamp','review_creation_date','review_comment_title',
             'review_comment_message', 'review_id', 'product_name_lenght',
             'product_description_lenght', 'product_photos_qty', 'product_weight_g',
             'product_length_cm', 'product_height_cm', 'product_width_cm',
             'customer_zip_code_prefix', 'seller_id', 'shipping_limit_date',
             'product_category_name'], axis=1, inplace = True)

# %%
all_df.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "order_id": "count"
}).sort_values(by = "price", ascending = False)
# Out:
#                                                   price  order_id
# customer_state product_category_name_english
# SP             bed bath table                 484058.24      5309
#                health beauty                  463534.30      4222
#                watches gifts                  435706.92      2283
#                sports leisure                 388285.98      3686
#                computers accessories          354863.98      3200
# ...                                                 ...       ...
# AL             drinks                             15.49         1
# ES             home comfort 2                     12.90         1
# PR             home comfort 2                     12.90         1
# BA             home comfort 2                     12.90         1
# MS             costruction tools tools             6.80         1
#
# [1356 rows x 2 columns]

# %% [markdown]
# **Convert `all_df` to csv**

# %%
all_df.to_csv('main_data.csv', index=False)

# %% [markdown]
# # Visualization & Explanatory Analysis

# %% [markdown]
# ## 1. Which items are the most popular?

# %%
plt.figure(figsize=(9,5))
sns.countplot(data = all_df, x = "product_category_name_english",
              palette = "Greens_r",
              order=all_df.product_category_name_english.value_counts().iloc[:5].index)
plt.title("Top 5 Most Popular Product Categories", fontsize = 15)
plt.ylabel("")
plt.xlabel("")
plt.show()

# %%
temp = all_df.groupby(by="customer_state").order_id.count().sort_values(ascending = False).reset_index()

# %%
top_states = temp.nlargest(5, 'order_id').customer_state.to_list()
temp_df = all_df[all_df['customer_state'].isin(top_states)]
temp_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5       a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6       136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7       6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# ...                                  ...                               ...
# 114039  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 114040  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 114042  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 114043  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 114044  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ## 2. Which top 5 states give the highest revenue?

# %%
plt.figure(figsize=(9,5))
sns.countplot(data = all_df, x = "customer_state",
              palette = "Greens_r",
              order=all_df.customer_state.value_counts().iloc[:5].index)
plt.title("Top 5 Customer States", fontsize = 15)
plt.ylabel("")
plt.xlabel("")
plt.show()

# %% [markdown]
# ## 3. How price and delivery time affect customer review scores?

# %%
corr_mat = all_df[['delivery_time', 'price', 'review_score']].corr()

plt.figure(figsize=(9, 5))
sns.heatmap(corr_mat, annot=True, cmap='coolwarm', fmt=".3f")
plt.title('Correlation between Price, Delivery Time, and Review Score')
plt.show()

# %% [markdown]
# ## 4. How is the company performance based on customer review scores?

# %%
rating = all_df['review_score'].value_counts(ascending=False)
plt.pie(
    x=rating,
    labels=all_df.review_score.value_counts().iloc[:5].index,
    autopct='%1.1f%%',
    explode=(0, 0, 0, 0,0)
)
plt.title("Customer Rating Distribution", fontsize = 15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f00c252cdf1> in <cell line: 1>()
# ----> 1 rating = all_df['review_score'].value_counts(ascending=False)
#       2 plt.pie(
#       3     x=rating,
#       4     labels=all_df.review_score.value_counts().index,
#       5     autopct='%1.1f%%',
#
# NameError: name 'all_df' is not defined

# %% [markdown]
# ## 5. Who are the top customers based on their recency, frequency, and monetary value?

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max",
    "order_id": "nunique",
    "price": "sum"
})
rfm_df.columns = ["customer_id", "last_order", "frequency", "monetary"]

rfm_df["last_order"] = rfm_df["last_order"].dt.date
recent_date = all_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["last_order"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("last_order", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      337
# 1  000161a058600d5901f007fab4c27140          1     54.90      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      596
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      427
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      198

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(25, 6))

colors = ["#b8d8be", "#b8d8be", "#b8d8be", "#b8d8be", "#b8d8be"]
xx = rfm_df.sort_values(by="recency", ascending=True).head(5)
sns.barplot(y="recency", x="customer_id", data=xx, palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].yaxis.set_ticks(range(0,19,2))
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %% [markdown]
# # Conclusion
# 1. Which items are the most popular?
#
# Five most popular item categories are bed bath table, health beauty, sports leisure, furniture decor, and computers accessories.
#
# 2. Which states have the highest revenue?
#
# Top 5 states with the highest revenue are SP, RJ, MG, RS, and PR.
#
# 3. How price and delivery time affect customer review scores?
#
# Based on correlation analysis; price, delivery time, and customer review scores have very low to no correlations. This shows that price and delivery time do not affect review scores given by the customers.
#
# 4. How is the company performance based on customer review scores?
#
# Based on the pie chart, 56.5% customers give 5 star ratings and 19.0% customers give 4 star ratings. This shows that most customers are satisfied with their orders.
#
# 5. Who are the top customers based on their recency, frequency, and monetary value?
#
# The RFM analysis shows that top customers make new order between 0 to 18 days from their last purchase, and spend about 6000 to 13000 on their purchase, and make 1 purchase.
